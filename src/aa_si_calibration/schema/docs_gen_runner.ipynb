# %%
# Run schema_docs_generator on standardized_calibration_file_schema.json
from pathlib import Path
from schema_docs_generator import generate_schema_docs, DEFAULT_SCHEMA_PATH, DEFAULT_OUTPUT_PATH

# You can customize these paths if needed
schema_path = DEFAULT_SCHEMA_PATH
output_path = DEFAULT_OUTPUT_PATH

generate_schema_docs(schema_path=schema_path, output_path=output_path)
print(f"Documentation generated at: {output_path}")
# Out:
# == Generating c:\Users\brett.layman\Documents\AA-SI\AA-SI_calibration\src\aa_si_calibration\schema\standardized_calibration_file_schema.md ==
# == Generated c:\Users\brett.layman\Documents\AA-SI\AA-SI_calibration\src\aa_si_calibration\schema\standardized_calibration_file_schema.md in 0:00:00.294848 ==
# Documentation generated at: c:\Users\brett.layman\Documents\AA-SI\AA-SI_calibration\src\aa_si_calibration\schema\standardized_calibration_file_schema.md
